# %%
from __future__ import print_function, division

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model, load_model
from keras.optimizers import Adam

import matplotlib.pyplot as plt

import sys

import numpy as np

import os

from PIL import Image

from matplotlib.pyplot import imshow

from random import randrange

from scipy.interpolate import interp1d

# %%
model = load_model(r'C:\Users\Vee\Desktop\python\GAN\Anime DCGAN\generator.h5')
# Out:
# C:\Users\Vee\Anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
random = np.random.normal(0, 1, (1, 50))

# %%
result = model.predict(random)
result = np.array(result)
result = result.reshape(1,64,64,3)
result = result * 256
result = result.astype(int)
imshow(result[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
random2 = np.random.normal(0, 1, (1, 50))

# %%
result2 = model.predict(random2)
result2 = np.array(result2)
result2 = result2.reshape(1,64,64,3)
result2 = result2 * 256
result2 = result2.astype(int)
imshow(result2[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#fit a line between point1 and point2
points = 60
line = interp1d([1, points], np.vstack([random, random2]), axis=0)
for i in range(points):
    result = model.predict(line(i+1).reshape(1,50))
    result = np.array(result)
    result = result.reshape(1,64,64,3)
    result = result * 256
    result = result.astype(int)
    fig=plt.figure(figsize=(3, 3))
    plt.imshow(result[0])
    fig.add_subplot(1, 1, 1)
    fig.savefig(r"C:\Users\Vee\Desktop\python\GAN\walk\image_%d.png" % i)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# C:\Users\Vee\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # Save Image 1

# %%
fig=plt.figure(figsize=(3, 3))
plt.imshow(result[0])
fig.add_subplot(1, 1, 1)
fig.savefig(r"C:\Users\Vee\Desktop\python\GAN\Anime DCGAN\image_%d.png" % randrange(250000))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# C:\Users\Vee\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Save Image 2

# %%
fig=plt.figure(figsize=(3, 3))
plt.imshow(result2[0])
fig.add_subplot(1, 1, 1)
fig.savefig(r"C:\Users\Vee\Desktop\python\GAN\Anime DCGAN\image_%d.png" % randrange(250000))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# C:\Users\Vee\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # infinite loop

# %%
first = np.random.normal(0, 1, (1, 50))

# %%
fresult = model.predict(first)
fresult = np.array(fresult)
fresult = fresult.reshape(1,64,64,3)
fresult = fresult * 256
fresult = fresult.astype(int)
imshow(fresult[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
